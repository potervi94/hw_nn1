# %% [markdown]
# Ваша задача методом градієнтного спуску побудувати модель для прогнозу ціни на діаманти

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module3/data/diamonds.csv",
                 index_col=0)

df.head()

# %% [markdown]
# Формула моделі
# $$
#           pred = coef*carat + intercept
# $$
# * coef - ціна за один карат
# * intercept - витрати
#
#
# <br>
# <br>
# Формула для ображунку похибки
#
# $$
#           loss = mean((pred - price)^2)
# $$
#
# * pred - ціна, спрогнозована моделю
# * price - справжня ціна

# %%
# імпорт модуля
import torch
from torch.optim import SGD

carat = df['carat'].to_numpy()
price = df['price'].to_numpy()

# вага в каратах
carat = torch.tensor(carat, dtype=torch.float32)

# справжня ціна
price = torch.tensor(price, dtype=torch.float32)

# %%
# створіть тензори з градієнтом, оберіть довільне початкове значення, тип даних float32
coef = torch.tensor(1.0, dtype=torch.float32, requires_grad=True)
intercept = torch.tensor(1.0, dtype=torch.float32, requires_grad=True)

# вкажіть навчальний крок
learning_rate = 0.01

# визначення оптимізатора
optimizer = SGD([coef, intercept], lr=learning_rate)

# основний цикл
for t in range(2000):
    # обрахуйте прогноз моделі за формулою наведеною вище
    pred = coef * carat + intercept

    # обрахуйте похибку між справжньою ціною та прогнозованою
    loss = torch.mean((pred - price) ** 2)

    # виведіть значення похибки для кожного сотого кроку
    if t % 100 == 0:
        print(f"Крок {t}: loss = {loss.item():.2f}, coef = {coef.item():.2f}, intercept = {intercept.item():.2f}")

    # обрахуйте градієнти по метриці
    loss.backward()

    # градієнтний спуск
    optimizer.step()
    optimizer.zero_grad()
# Out:
# Крок 0: loss = 31364628.00, coef = 1.00, intercept = 1.00
# Крок 100: loss = 6464010.50, coef = 3568.90, intercept = 1440.23
# Крок 200: loss = 4804659.50, coef = 4579.94, intercept = 651.98
# Крок 300: loss = 3829238.50, coef = 5308.36, intercept = -11.83
# Крок 400: loss = 3249155.00, coef = 5868.58, intercept = -525.38
# Крок 500: loss = 2904172.50, coef = 6300.57, intercept = -921.47
# Крок 600: loss = 2699008.00, coef = 6633.71, intercept = -1226.93
# Крок 700: loss = 2576994.00, coef = 6890.61, intercept = -1462.49
# Крок 800: loss = 2504431.75, coef = 7088.73, intercept = -1644.15
# Крок 900: loss = 2461278.00, coef = 7241.52, intercept = -1784.24
# Крок 1000: loss = 2435613.50, coef = 7359.34, intercept = -1892.27
# Крок 1100: loss = 2420351.25, coef = 7450.20, intercept = -1975.58
# Крок 1200: loss = 2411274.25, coef = 7520.27, intercept = -2039.83
# Крок 1300: loss = 2405876.25, coef = 7574.31, intercept = -2089.38
# Крок 1400: loss = 2402666.00, coef = 7615.98, intercept = -2127.59
# Крок 1500: loss = 2400756.75, coef = 7648.12, intercept = -2157.05
# Крок 1600: loss = 2399621.25, coef = 7672.90, intercept = -2179.78
# Крок 1700: loss = 2398946.00, coef = 7692.02, intercept = -2197.30
# Крок 1800: loss = 2398544.50, coef = 7706.75, intercept = -2210.82
# Крок 1900: loss = 2398305.50, coef = 7718.12, intercept = -2221.24

# %% [markdown]
# # Результат

# %%
coef.item(), intercept.item()

# %% [markdown]
# # Порівняйте результат з sklearn

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
X_train = df.drop(columns=['price'])
y_train = df['price']
# тренування
model.fit(X_train, y_train)

# %%
model.coef_[0], model.intercept_
